# %% [markdown]
# Dataset download link: https://unomaha.box.com/shared/static/emdbt8qdkq6p5841o1dbcwe01zlzn7p2.zip

# %%
from glob import glob
import numpy as np
import PIL.Image
from tqdm import tqdm
from pathlib import Path
from joblib import Parallel, delayed
import multiprocessing
import urllib.request
import tarfile
import zipfile
import subprocess
import sys
import os

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import tensorflow as tf
tf.compat.v1.enable_eager_execution()

WORK = os.getenv('WORK')
sys.path.insert(0, f'{WORK}/ADA_Project')
sys.path.insert(0, f'{WORK}/ADA_Project/StyleGAN2-ADA')

import DeepFAMS

WORK, PROJ_DIR = DeepFAMS.utils.set_env()
# Out:
# Tensorflow version: 1.14.0

# %%
RAW_IMGS_DIR, RESIZED_IMGS_DIR, DATA_CUSTOM_DIR, TRAIN_RUNS_DIR = DeepFAMS.utils.return_dirs(
    PROJ_DIR, 'ANIME-FACES')

# %%
# RAW_IMGS_DIR_ = glob(f'{RAW_IMGS_DIR}/waifus/images/*')
# RAW_IMGS_DIR_ = [x for x in RAW_IMGS_DIR_ if Path(x).suffix in ['.jpg', '.png', '.jpeg']]
# len(RAW_IMGS_DIR_)
# Out:
# 15424

# %%
# def select_imgs(img):
#     image = PIL.Image.open(img)
#     if image.size[0] >= 256 and image.size[1] >= 256:
#         return img

# num_cores = multiprocessing.cpu_count() - 1
# results = Parallel(n_jobs=num_cores)(delayed(select_imgs)(img) for img in RAW_IMGS_DIR_)

# %%
# fraw_imgs = [x for x in results if x is not None]
# len(fraw_imgs)
# Out:
# 10183

# %%
# for x in tqdm(fraw_imgs):
#     DeepFAMS.preprocessing.resize_imgs(x, (256, 256), RESIZED_IMGS_DIR)
# Out:
#  48%|████▊     | 4931/10183 [02:39<02:55, 29.87it/s]/home/chaselab/malyetama/.local/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:802: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 100%|██████████| 10183/10183 [05:23<00:00, 31.46it/s]

# %%
# print(f'Raw: {len(fraw_imgs)}, Resized: {len(glob(f"{RESIZED_IMGS_DIR}/*"))}')
# Out:
# Raw: 10183, Resized: 10183

# %%
# DeepFAMS.preprocessing.tf_record_exporter(tfrecord_dir=DATA_CUSTOM_DIR, image_dir=RESIZED_IMGS_DIR, shuffle=1)
# Out:
# Loading images from "/work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized"
# Creating dataset "/work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_custom"
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5209.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3607.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6535.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12737.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2227.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2020.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7808.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14923.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5219.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13241.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10350.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6506.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10629.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/852.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5724.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/77.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4875.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6479.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9658.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10984.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3178.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5671.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5728.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11657.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9137.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6342.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5448.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13960.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11024.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/15130.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7118.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/321.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3613.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11935.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9204.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5010.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11559.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6302.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4451.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10205.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3179.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12377.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11466.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10511.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/820.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10164.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5919.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1879.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14444.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12797.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9652.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/582.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11651.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8806.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1427.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4893.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5509.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8784.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11047.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/15308.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10053.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11422.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14866.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5725.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6685.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4302.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12499.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13008.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5730.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/15310.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7112.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9284.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14175.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10035.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11547.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6310.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4572.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10765.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10868.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10510.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9484.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1897.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6441.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8121.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11039.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10676.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8066.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6343.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11087.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5729.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3271.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14751.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2032.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4944.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6656.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11193.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3201.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9736.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6774.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9128.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6174.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11679.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6919.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6890.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8204.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4497.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9433.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13670.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6289.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5873.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10889.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9532.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13362.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6102.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6581.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/663.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9435.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1167.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10424.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3869.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1903.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11104.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3200.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9916.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8773.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2747.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9890.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1036.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9827.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12798.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8054.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4945.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7730.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11088.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1904.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4923.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5999.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6256.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2232.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1035.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/78.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11319.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4925.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7842.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14831.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9866.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10515.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/15082.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6420.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9434.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10635.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5689.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9846.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4395.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8392.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11275.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3987.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3578.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2138.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5593.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9060.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9258.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9138.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6308.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6565.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5495.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/81.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12937.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2776.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10991.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8993.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6865.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7156.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9715.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11799.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10634.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7683.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1676.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/79.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10869.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10657.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5879.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3801.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/1942.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3114.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10015.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4028.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4584.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7230.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3992.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4935.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7412.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10036.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12371.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/5158.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10351.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/6779.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/763.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/8355.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11175.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12639.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3223.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14253.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12614.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10073.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/12490.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13197.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14839.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4823.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/332.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13218.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/11589.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4541.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/10559.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3131.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/2208.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/787.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/13473.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14117.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/15261.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/14100.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7703.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/4885.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3971.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/7334.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/9998.jpg
# axes don't match array
# Failed to export /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_resized/3177.jpg
# Added 9956 images.

# %%
DeepFAMS.utils.execute('nvidia-smi')
# Out:
# Mon Mar 29 16:03:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.06    Driver Version: 450.51.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100S-PCI...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   29C    P0    24W / 250W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
DeepFAMS.utils.executePopen(f'''#!/bin/bash
module load anaconda
module load compiler/gcc/4.7
module load cuda
$WORK/.conda/envs/ada-env/bin/python $WORK/ADA_Project/StyleGAN2-ada/train.py \
--outdir={TRAIN_RUNS_DIR} \
--gpus=1 \
--data={DATA_CUSTOM_DIR} \
--snap=1 \
--kimg=1''', PROJ_DIR)
# Out:
# Training options:
#
# {
#
#   "G_args": {
#
#     "func_name": "training.networks.G_main",
#
#     "fmap_base": 8192,
#
#     "fmap_max": 512,
#
#     "mapping_layers": 2,
#
#     "num_fp16_res": 4,
#
#     "conv_clamp": 256
#
#   },
#
#   "D_args": {
#
#     "func_name": "training.networks.D_main",
#
#     "mbstd_group_size": 4,
#
#     "fmap_base": 8192,
#
#     "fmap_max": 512,
#
#     "num_fp16_res": 4,
#
#     "conv_clamp": 256
#
#   },
#
#   "G_opt_args": {
#
#     "beta1": 0.0,
#
#     "beta2": 0.99,
#
#     "learning_rate": 0.0025
#
#   },
#
#   "D_opt_args": {
#
#     "beta1": 0.0,
#
#     "beta2": 0.99,
#
#     "learning_rate": 0.0025
#
#   },
#
#   "loss_args": {
#
#     "func_name": "training.loss.stylegan2",
#
#     "r1_gamma": 0.8192
#
#   },
#
#   "augment_args": {
#
#     "class_name": "training.augment.AdaptiveAugment",
#
#     "tune_heuristic": "rt",
#
#     "tune_target": 0.6,
#
#     "apply_func": "training.augment.augment_pipeline",
#
#     "apply_args": {
#
#       "xflip": 1,
#
#       "rotate90": 1,
#
#       "xint": 1,
#
#       "scale": 1,
#
#       "rotate": 1,
#
#       "aniso": 1,
#
#       "xfrac": 1,
#
#       "brightness": 1,
#
#       "contrast": 1,
#
#       "lumaflip": 1,
#
#       "hue": 1,
#
#       "saturation": 1
#
#     }
#
#   },
#
#   "num_gpus": 1,
#
#   "image_snapshot_ticks": 1,
#
#   "network_snapshot_ticks": 1,
#
#   "train_dataset_args": {
#
#     "path": "/work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_custom",
#
#     "max_label_size": 0,
#
#     "resolution": 256,
#
#     "mirror_augment": false
#
#   },
#
#   "metric_arg_list": [
#
#     {
#
#       "name": "fid50k_full",
#
#       "class_name": "metrics.frechet_inception_distance.FID",
#
#       "max_reals": null,
#
#       "num_fakes": 50000,
#
#       "minibatch_per_gpu": 8,
#
#       "force_dataset_args": {
#
#         "shuffle": false,
#
#         "max_images": null,
#
#         "repeat": false,
#
#         "mirror_augment": false
#
#       }
#
#     }
#
#   ],
#
#   "metric_dataset_args": {
#
#     "path": "/work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_custom",
#
#     "max_label_size": 0,
#
#     "resolution": 256,
#
#     "mirror_augment": false
#
#   },
#
#   "total_kimg": 1,
#
#   "minibatch_size": 16,
#
#   "minibatch_gpu": 16,
#
#   "G_smoothing_kimg": 5.0,
#
#   "G_smoothing_rampup": 0.05,
#
#   "run_dir": "/work/chaselab/malyetama/ADA_Project/training_runs/ANIME-FACES_training-runs/00001-ANIME-FACES_custom-auto1-kimg1"
#
# }
#
#
#
# Output directory:  /work/chaselab/malyetama/ADA_Project/training_runs/ANIME-FACES_training-runs/00001-ANIME-FACES_custom-auto1-kimg1
#
# Training data:     /work/chaselab/malyetama/ADA_Project/datasets/ANIME-FACES_custom
#
# Training length:   1 kimg
#
# Resolution:        256
#
# Number of GPUs:    1
#
#
#
# Creating output directory...
#
# Loading training set...
#
# Image shape: [3, 256, 256]
#
# Label shape: [0]
#
#
#
# Constructing networks...
#
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
#
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
#
#
#
# G                             Params    OutputShape         WeightShape
#
# ---                           ---       ---                 ---
#
# latents_in                    -         (?, 512)            -
#
# labels_in                     -         (?, 0)              -
#
# G_mapping/Normalize           -         (?, 512)            -
#
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
#
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
#
# G_mapping/Broadcast           -         (?, 14, 512)        -
#
# dlatent_avg                   -         (512,)              -
#
# Truncation/Lerp               -         (?, 14, 512)        -
#
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
#
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
#
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
#
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
#
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
#
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
#
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
#
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
#
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
#
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
#
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
#
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
#
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
#
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
#
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
#
# G_synthesis/64x64/Conv0_up    1442561   (?, 256, 64, 64)    (3, 3, 512, 256)
#
# G_synthesis/64x64/Conv1       721409    (?, 256, 64, 64)    (3, 3, 256, 256)
#
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
#
# G_synthesis/64x64/ToRGB       132099    (?, 3, 64, 64)      (1, 1, 256, 3)
#
# G_synthesis/128x128/Conv0_up  426369    (?, 128, 128, 128)  (3, 3, 256, 128)
#
# G_synthesis/128x128/Conv1     213249    (?, 128, 128, 128)  (3, 3, 128, 128)
#
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
#
# G_synthesis/128x128/ToRGB     66051     (?, 3, 128, 128)    (1, 1, 128, 3)
#
# G_synthesis/256x256/Conv0_up  139457    (?, 64, 256, 256)   (3, 3, 128, 64)
#
# G_synthesis/256x256/Conv1     69761     (?, 64, 256, 256)   (3, 3, 64, 64)
#
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
#
# G_synthesis/256x256/ToRGB     33027     (?, 3, 256, 256)    (1, 1, 64, 3)
#
# ---                           ---       ---                 ---
#
# Total                         23191522
#
#
#
#
#
# D                    Params    OutputShape         WeightShape
#
# ---                  ---       ---                 ---
#
# images_in            -         (?, 3, 256, 256)    -
#
# labels_in            -         (?, 0)              -
#
# 256x256/FromRGB      256       (?, 64, 256, 256)   (1, 1, 3, 64)
#
# 256x256/Conv0        36928     (?, 64, 256, 256)   (3, 3, 64, 64)
#
# 256x256/Conv1_down   73856     (?, 128, 128, 128)  (3, 3, 64, 128)
#
# 256x256/Skip         8192      (?, 128, 128, 128)  (1, 1, 64, 128)
#
# 128x128/Conv0        147584    (?, 128, 128, 128)  (3, 3, 128, 128)
#
# 128x128/Conv1_down   295168    (?, 256, 64, 64)    (3, 3, 128, 256)
#
# 128x128/Skip         32768     (?, 256, 64, 64)    (1, 1, 128, 256)
#
# 64x64/Conv0          590080    (?, 256, 64, 64)    (3, 3, 256, 256)
#
# 64x64/Conv1_down     1180160   (?, 512, 32, 32)    (3, 3, 256, 512)
#
# 64x64/Skip           131072    (?, 512, 32, 32)    (1, 1, 256, 512)
#
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
#
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
#
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
#
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
#
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
#
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
#
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
#
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
#
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
#
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
#
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
#
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
#
# Output               513       (?, 1)              (512, 1)
#
# ---                  ---       ---                 ---
#
# Total                24001089
#
#
#
# Exporting sample images...
#
# Replicating networks across 1 GPUs...
#
# Initializing augmentations...
#
# Setting up optimizers...
#
# Constructing training graph...
#
# Finalizing training ops...
#
# Initializing metrics...
#
# Training for 1 kimg...
#
#
#
# tick 0     kimg 0.1      time 1m 29s       sec/tick 25.4    sec/kimg 396.79  maintenance 63.8   gpumem 7.1   augment 0.000
# Evaluating metrics...
#
# Calculating real image statistics for fid50k_full...
#
# network-snapshot-000000        time 6m 23s       fid50k_full 332.4995
#
# tick 1     kimg 1.0      time 8m 38s       sec/tick 26.6    sec/kimg 27.69   maintenance 401.9  gpumem 7.1   augment 0.001
#
# Evaluating metrics...
#
# network-snapshot-000001        time 4m 24s       fid50k_full 369.8230
#
#
#
# Exiting...

# %%
for num in range(-1, -10, -1):
    files = DeepFAMS.utils.last_snap(num, TRAIN_RUNS_DIR)
    if files != []:
        break

latest_snap = sorted(files)[-1]
print(latest_snap)
# Out:
# /work/chaselab/malyetama/ADA_Project/training_runs/ANIME-FACES_training-runs/00001-ANIME-FACES_custom-auto1-kimg1/network-snapshot-000001.pkl

# %%
run_desc, training_options = DeepFAMS.setup_training_options(
    gpus       = 2,
    snap       = 1,
    data       = DATA_CUSTOM_DIR,
    resume     = latest_snap
)

# %%
DeepFAMS.RunTraining(outdir=TRAIN_RUNS_DIR, seed=1000,
             dry_run=True, run_desc=run_desc, training_options=training_options)

# %%
tf.compat.v1.disable_eager_execution()
DeepFAMS.RunTraining(outdir=TRAIN_RUNS_DIR, seed=1000,
             dry_run=False, run_desc=run_desc, training_options=training_options)
